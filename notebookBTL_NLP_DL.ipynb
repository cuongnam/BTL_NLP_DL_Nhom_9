# %%
# !git clone https://github.com/cuongnam/BTL_NLP_DL_Nhom_9.git
# Out:
# Cloning into 'BTL_NLP_DL_Nhom_9'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 47 (delta 20), reused 40 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 5.77 MiB | 21.09 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# %cd BTL_NLP_DL_Nhom_9
# Out:
# /kaggle/working/BTL_NLP_DL_Nhom_9

# %%
# !pip install -r requirements.txt -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 63.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 108.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 80.5 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
# !mkdir -p src data/processed_bio data/processed_joint

# %%
# !python src/preprocess_bkee.py
# Out:
# Đang xử lý file dữ liệu: ./data/processed/train.json
# -> Đã xử lý xong! File đích: ./data/processed_bio/train_bio.json (Tổng số câu: 10959)
# Đang xử lý file dữ liệu: ./data/processed/dev.json
# -> Đã xử lý xong! File đích: ./data/processed_bio/dev_bio.json (Tổng số câu: 4301)
# Đang xử lý file dữ liệu: ./data/processed/train.json
# -> Đã xử lý xong! File đích: ./data/processed_joint/train_joint.json (Tổng số câu: 10959)
# Đang xử lý file dữ liệu: ./data/processed/dev.json
# -> Đã xử lý xong! File đích: ./data/processed_joint/dev_joint.json (Tổng số câu: 4301)

# %%
import wandb
wandb.login(key="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")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nguyencuong30062004 (nguyencuong30062004-dhdn) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python src/train_trigger_model.py
# Out:
# ...
# KHỞI CHẠY RUN 01: RULE-BASED TRIGGER
# ...
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: nguyencuong30062004 (nguyencuong30062004-dhdn) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /kaggle/working/BTL_NLP_DL_Nhom_9/wandb/run-20260627_175801-dikru0ly
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run run_01_rule_based_trigger
# wandb: ⭐️ View project at https://wandb.ai/nguyencuong30062004-dhdn/BKEE_Event_Extraction_LREC2024
# wandb: 🚀 View run at https://wandb.ai/nguyencuong30062004-dhdn/BKEE_Event_Extraction_LREC2024/runs/dikru0ly
# -> Đã xây dựng xong từ điển chứa 676 từ khóa kích hoạt.
#
# --- KẾT QUẢ NGHIỆM THU RUN 01 ---
# Precision : 7.25%
# Recall    : 94.59%
# F1-score  : 13.46%
# ...
#
# ...

# %%
# !python src/train_phobert_models.py
# Out:
# KHỞI CHẠY RUN 03...
# ...
# config.json: 100%|█████████████████████████████| 678/678 [00:00<00:00, 2.86MB/s]
# vocab.txt: 895kB [00:00, 67.6MB/s]
# bpe.codes: 1.14MB [00:00, 111MB/s]
# tokenizer.json: 3.13MB [00:00, 138MB/s]
# pytorch_model.bin: 100%|█████████████████████| 540M/540M [00:06<00:00, 83.9MB/s]
# Loading weights:  79%|▊| 156/197 [00:00<00:00, 1944.33it/s, Materializing param=
# Loading weights: 100%|█| 197/197 [00:00<00:00, 1949.39it/s, Materializing param=
# RobertaForTokenClassification LOAD REPORT from: vinai/phobert-base-v2
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.dense.bias              | UNEXPECTED |
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# classifier.bias                 | MISSING    |
# ...

# %%
# !tar -czvf model_checkpoints.tar.gz ./saved_models
# Out:
# ./saved_models/
# ./saved_models/run_04/
# ./saved_models/run_04/checkpoint-2055/
# ./saved_models/run_04/checkpoint-2055/rng_state.pth
# ./saved_models/run_04/checkpoint-2055/config.json
# ./saved_models/run_04/checkpoint-2055/model.safetensors
# ./saved_models/run_04/checkpoint-2055/training_args.bin
# ./saved_models/run_04/checkpoint-2055/trainer_state.json
# ./saved_models/run_04/checkpoint-2055/scheduler.pt
# ./saved_models/run_04/checkpoint-2055/optimizer.pt
# ./saved_models/run_03/
# ./saved_models/run_03/checkpoint-2055/
# ./saved_models/run_03/checkpoint-2055/rng_state.pth
# ./saved_models/run_03/checkpoint-2055/config.json
# ./saved_models/run_03/checkpoint-2055/model.safetensors
# ./saved_models/run_03/checkpoint-2055/training_args.bin
# ./saved_models/run_03/checkpoint-2055/trainer_state.json
# ./saved_models/run_03/checkpoint-2055/scheduler.pt
# ./saved_models/run_03/checkpoint-2055/optimizer.pt
